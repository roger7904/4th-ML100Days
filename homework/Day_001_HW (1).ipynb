# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y-yp)**2)/len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 239.953
# The Mean absolute error is 12.600

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要：武漢肺炎疫情逐漸升溫，並且尚未能找出解藥，跟SARS皆為冠狀病毒，傳染方式類似，會是研究武漢肺炎解藥的一個參考方向。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)：資料由國家生物技術信息中心（NCBI）取得，此單位研究的數據可公開獲得，並且數據下載後無需修改。
#
# 3. 蒐集而來的資料型態為何：有CSV格式的序列比對的表格、FASTA格式的SARS病毒分離株Rs4247完整基因組、XML格式的RNA收錄。
#
# 4. 這組資料想解決的問題如何評估：首先，研究人員注意到SARS病毒COVID-19之間的相似之處，並懷疑其起源於該病毒的蝙蝠。將這些收集來的資料，以數據化分析的方式製作成更視覺化的圖表，來比對SARS病毒COVID-19之間的相似之處，以此輔助新型冠狀病毒的研發。
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)：核心問題：車價如何訂定，人潮集中於那些時段，如何將客戶配對到最合適的車主。假設能夠得知載客的巔峰時期，依此為標準配置價格和車主人數的分配，適時減少人力分配，並將價格最大化，再來就是假設能讓每個客戶能最快搜尋到最近的車主，也能大大降低時間的成本。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)：會用到的資料有，市場上平均載客的跳表價格，不同時間點的載客價格，巔峰的叫車時間，不同地點的叫車人數，各地點的交通狀況。如何蒐集這些資料：使用交通部開放資料平台計程車營運狀況調查、即時路況資訊流通平台
#
# 3. 蒐集而來的資料型態為何：交通部開放資料平台計程車營運狀況調查->CSV，即時路況資訊流通平台->VD、CMS、CCTV、AVI
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)：藉由巔峰時間提高計價，達到供需平衡，控制叫車人數，提高價格也使更多的司機能在這段時間到此地段等客，人數少的地方自然就不會有這麼多的司機，藉由分析即時路況，能替客戶尋找最適合的車主，可以配合演算法，讓所有客戶等的時間總和能夠最小化，避免有些情況例如：分配一個司機給最近用戶時，卻使另一客戶需要等待更長的時間。
